# %%
import pandas as pd
from pathlib import Path
from testgen.analysis_utils import *
from functools import reduce

# %%
labels = get_sensors_labels()
labels
# Out:
# array(['Acc', 'WSA', 'WS', 'YR', 'ST'], dtype='<U3')

# %%
# read results file
base_path = Path().cwd()
results_path = base_path.parent / "results"
    
result_files = get_best_results(results_path, "single_[!dropped]*n-1*.json")

# %%
def read_and_process(filename):
    res, _ = result_to_df(labels, filename, results_path)

    res = res[["requirement", "accuracy"]]
    res.rename(
        columns={"accuracy": filename.stem[: filename.stem.find("_acc")]},
        inplace=True,
    )

    return res


dfs = [read_and_process(f) for f in result_files]

# %%
df = reduce(
    lambda left, right: pd.merge(left, right, on=["idx", "requirement"], how="inner"),
    dfs
)

# %%
df
# Out:
#                                            requirement  \
# idx
# 0    The vehicle control system shall have the capa...
# 1    The system must process acceleration requests ...
# 2    In the event of conflicting signals from the a...
# 3    Should the primary control system fail, the ac...
# 4    The control system connected to the accelerato...
# ..                                                 ...
# 132  The vehicle's steering control system must ref...
# 133  The vehicle's control systems must assist the ...
# 134  The system should  prevent oversteering and lo...
# 135  The vehicle control system shall ensure a stab...
# 136  An automated parking assistance system must na...
#
#      single_gpt-4o-mini_n-1  single_llama-3.2-11b-text-preview_n-1  \
# idx
# 0                      True                                   True
# 1                      True                                   True
# 2                      True                                   True
# 3                      True                                   True
# 4                      True                                   True
# ..                      ...                                    ...
# 132                    True                                  False
# 133                    True                                   True
# 134                    True                                   True
# 135                    True                                   True
# 136                    True                                  False
#
#      single_llama-3.2-3b-preview_n-1  single_llama-3.2-90b-text-preview_n-1  \
# idx
# 0                               True                                   True
# 1                               True                                   True
# 2                               True                                   True
# 3                               True                                   True
# 4                               True                                   True
# ..                               ...                                    ...
# 132                            False                                  False
# 133                            False                                   True
# 134                            False                                   True
# 135                            False                                   True
# 136                            False                                   True
#
#      single_mixtral-8x7b-32768_n-1
# idx
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                             True
# ..                             ...
# 132                           True
# 133                          False
# 134                           True
# 135                           True
# 136                           True
#
# [137 rows x 6 columns]
