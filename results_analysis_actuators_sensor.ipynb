# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from testgen.analysis_utils import *

# %%
base = Path().cwd()

data_path = base / "data"
results_path = base / "results"

# %%
sensor_df = pd.read_excel(data_path / "sensor_requirements.xlsx")
sensor_df = sensor_df[["requirement"]].copy()
sensor_df["is_actuator"] = 0

actuator_df = pd.read_excel(data_path / "actuator_requirements.xlsx")
actuator_df.columns = ["requirement"]
actuator_df["is_actuator"] = 1

df = pd.concat([actuator_df, sensor_df]).reset_index(drop=True)

# %%
ax = df["is_actuator"].value_counts().plot.bar(
    title="Distribution of Actuators and Sensors",
    color="teal",
)

_ = ax.bar_label(ax.containers[0])

# %%
results = get_best_results(results_path, "sensor-actuator*.json")

results = pd.DataFrame.from_dict(
    results, orient="index", columns=["n", "acc"]
)
results.index = results.index.str.split("_").str[0]
results.index.name = "model"

# %%
# Create the grouped bar plot using Seaborn
plt.figure(figsize=(12, 6))  # Adjust figure size for better readability
ax = sns.barplot(x="model", y="acc", hue="n", data=results, palette="viridis")

# Add data labels
for p in ax.patches:
    ax.annotate(
        format(p.get_height(), ".3f"),
        (p.get_x() + p.get_width() / 2.0, p.get_height()),
        ha="center",
        va="center",
        xytext=(0, 5),
        textcoords="offset points",
        fontsize=10,
    )

# Add title and labels
plt.title("Actuator vs Sensor Model Accuracy")
plt.xlabel("Base Model")
plt.ylabel("Accuracy")

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=0, ha="right")

# Display the plot
plt.tight_layout()  # Adjust layout to prevent labels from overlapping
plt.show()

# %%
def plot_summarize(c, summarize_):
    ax = summarize_["accuracy"].plot.bar(
        title="Accuracy per Sensor",
        xlabel="",
    )

    _ = ax.bar_label(ax.containers[0])

# %%
def investigate_sensor_in_file(ts, file):
    t_, _ = result_to_df(labels, file, results_path)
    return t_[(t_["true_label"] == ts) & (t_["accuracy"] == False)]["pred_label"].value_counts()

# %%
investigate_sensor_in_file("ST", results_single[0])
# Out:
# Series([], Name: count, dtype: int64)

# %%
stats_single, summarize_single = analyze_multiple(labels, results_single, results_path)

# %%
stats_single
# Out:
#                    type   model_name  accuracy  number_of_reqs  total_tokens  \
# number_examples
# 1                single  gpt-4o-mini  0.934307             137        108961
# 3                single  gpt-4o-mini  0.905109             137        188421
# 5                single  gpt-4o-mini  0.905109             137        264593
# 8                single  gpt-4o-mini  0.905109             137        381043
#
#                  total_completion_tokens  avg_token_per_req  \
# number_examples
# 1                                   1781         795.335766
# 3                                   1781        1375.335766
# 5                                   1781        1931.335766
# 8                                   1781        2781.335766
#
#                  avg_completion_token_per_req  avg_time_per_req
# number_examples
# 1                                        13.0          0.931720
# 3                                        13.0          3.557572
# 5                                        13.0          4.004780
# 8                                        13.0          4.469258

# %%
metrics_n_single = summarize_single[summarize_single["sensors"] == "All"].set_index("number_examples").iloc[:, -4:]
metrics_n_single.index = metrics_n_single.index.astype("str")

ax = metrics_n_single.plot.line(
    yticks=[float(r/100) for r in range(80, 101, 5)],
    linewidth=2,
    xlabel="n-Shots",
    title="n-Shots Learning for all Sensors [Single]",
)

ax.legend(loc='lower left')

# %%
metrics_n_sensor_single = summarize_single[(summarize_single["sensors"] != "All") & (summarize_single["number_examples"] == 1)].set_index(["sensors"]).iloc[:, -4:]

ax = metrics_n_sensor_single.plot.bar(
    linewidth=2,
    xlabel="Sensors",
    title="Metrics per Sensor for One-Shot Learning [Single]",
    align='edge',
)

ax.legend(loc='lower right')

# %%
metrics_n_sensor_single
# Out:
#                           accuracy  precision  recall   f1
# sensors
# Acc & WSA & WS & YR & ST       1.0        1.0     1.0  1.0

# %%
stats_bulk, summarize_bulk = analyze_multiple(labels, results_bulk, results_path)

# %%
stats_bulk
# Out:
#         type   model_name  number_examples  accuracy  number_of_reqs  \
# type_n
# 2       bulk  gpt-4o-mini                1  0.889706              68
# 3       bulk  gpt-4o-mini                1  0.866667              45
# 5       bulk  gpt-4o-mini                1  0.837037              27
# 8       bulk  gpt-4o-mini                1  0.823529              17
#
#         total_tokens  total_completion_tokens  avg_token_per_req  \
# type_n
# 2              59347                     2108         436.375000
# 3              40690                     2160         301.407407
# 5              26699                     2160         197.770370
# 8              19149                     2176         140.801471
#
#         avg_completion_token_per_req  avg_time_per_req
# type_n
# 2                               15.5          0.476348
# 3                               16.0          0.186321
# 5                               16.0          0.165171
# 8                               16.0          0.149402

# %%
metrics_n_bulk = summarize_bulk[summarize_bulk["sensors"] == "All"].set_index("type_n").iloc[:, -4:]
metrics_n_bulk.index = metrics_n_bulk.index.astype("str")

ax = metrics_n_bulk.plot.line(
    yticks=[float(r/100) for r in range(80, 101, 5)],
    linewidth=2,
    xlabel="Number of Requirements",
    title="Multiple Requirements - One-Shot [Bulk]",
)

ax.legend(loc='lower left')

# %%
metrics_n_sensor_bulk = summarize_bulk[(summarize_bulk["sensors"] != "All") & (summarize_bulk["type_n"] == 2)].set_index(["sensors"]).iloc[:, -4:]

ax = metrics_n_sensor_bulk.plot.bar(
    linewidth=2,
    xlabel="Sensors",
    title="Two Requirements - One-Shot [Bulk]",
    align='edge',
)

ax.legend(loc='lower right')

# %%
metrics_n_sensor_bulk
# Out:
#                           accuracy  precision  recall   f1
# sensors
# Acc & WSA & WS & YR & ST       1.0        1.0     1.0  1.0

# %%
stats_bulk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 2 to 8
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   type                          4 non-null      object
#  1   model_name                    4 non-null      object
#  2   number_examples               4 non-null      int64
#  3   accuracy                      4 non-null      float64
#  4   number_of_reqs                4 non-null      int64
#  5   total_tokens                  4 non-null      int64
#  6   total_completion_tokens       4 non-null      int64
#  7   avg_token_per_req             4 non-null      float64
#  8   avg_completion_token_per_req  4 non-null      float64
#  9   avg_time_per_req              4 non-null      float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 352.0+ bytes

# %%
metrics_n_bulk_t = stats_bulk[["avg_token_per_req"]].merge(metrics_n_bulk, on="type_n")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 metrics_n_bulk_t = stats_bulk[["avg_token_per_req"]].merge(metrics_n_bulk, on="type_n")
#
# File /mnt/d/scripts/hil/hil-test-case-gen/.venv/lib/python3.12/site-packages/pandas/core/frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)  10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
#   10840         right_index=right_index,
#   10841         sort=sort,
#   10842         suffixes=suffixes,
#   10843         copy=copy,
#   10844         indicator=indicator,
#   10845         validate=validate,
#   10846     )
#
# File /mnt/d/scripts/hil/hil-test-case-gen/.venv/lib/python3.12/site-packages/pandas/core/reshape/merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)    167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
#     174         on=on,
#     175         left_on=left_on,
#     176         right_on=right_on,
#     177         left_index=left_index,
#     178         right_index=right_index,
#     179         sort=sort,
#     180         suffixes=suffixes,
#     181         indicator=indicator,
#     182         validate=validate,
#     183     )
#     184     return op.get_result(copy=copy)
#
# File /mnt/d/scripts/hil/hil-test-case-gen/.venv/lib/python3.12/site-packages/pandas/core/reshape/merge.py:807, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     803 self._validate_tolerance(self.left_join_keys)
#     805 # validate the merge keys dtypes. We may need to coerce
#     806 # to avoid incompatible dtypes
# --> 807 self._maybe_coerce_merge_keys()
#     809 # If argument passed to validate,
#     810 # check if columns specified as unique
#     811 # are in fact unique.
#     812 if validate is not None:
#
# File /mnt/d/scripts/hil/hil-test-case-gen/.venv/lib/python3.12/site-packages/pandas/core/reshape/merge.py:1508, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1502     # unless we are merging non-string-like with string-like
#    1503     elif (
#    1504         inferred_left in string_types and inferred_right not in string_types
#    1505     ) or (
#    1506         inferred_right in string_types and inferred_left not in string_types
#    1507     ):
# -> 1508         raise ValueError(msg)
#    1510 # datetimelikes must match exactly
#    1511 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on int64 and object columns for key 'type_n'. If you wish to proceed you should use pd.concat

# %%
ax = metrics_n_bulk_t.plot.line(
    xticks=metrics_n_bulk.index,
    # yticks=[float(r/100) for r in range(80, 101, 5)],
    linewidth=2,
    secondary_y=["avg_token_per_req"],
    xlabel="n-Shots",
    title="n-Shots Learning for all Sensors [Bulk]",
)

# %%
result_llms = get_best_results(results_path, "single_[!dropped]*n-1*.json")

# %%
stats_llm, summarize_llm = analyze_multiple(labels, result_llms, results_path)

# %%
stats_llm
# Out:
#                    type                  model_name  accuracy  number_of_reqs  \
# number_examples
# 1                single                 gpt-4o-mini  0.934307             137
# 1                single  llama-3.2-11b-text-preview  0.861314             137
# 1                single        llama-3.2-3b-preview  0.598540             137
# 1                single  llama-3.2-90b-text-preview  0.875912             137
# 1                single          mixtral-8x7b-32768  0.839416             137
#
#                  total_tokens  total_completion_tokens  avg_token_per_req  \
# number_examples
# 1                      108961                     1781         795.335766
# 1                      118098                     6252         862.029197
# 1                      113745                     2858         830.255474
# 1                      119194                     7348         870.029197
# 1                      134951                     5717         985.043796
#
#                  avg_completion_token_per_req  avg_time_per_req
# number_examples
# 1                                   13.000000          0.931720
# 1                                   45.635036          6.971447
# 1                                   20.861314          6.699515
# 1                                   53.635036          7.156187
# 1                                   41.729927         11.391009

# %%
metrics_n_llm = summarize_llm[summarize_llm["sensors"] == "All"].set_index("model_name").iloc[:, -4:]
metrics_n_llm.index = metrics_n_llm.index.astype("str")

metrics_n_llm
# Out:
#                             accuracy  precision  recall    f1
# model_name
# gpt-4o-mini                     0.93       0.97    0.93  0.95
# llama-3.2-11b-text-preview      0.86       0.91    0.86  0.88
# llama-3.2-3b-preview            0.60       0.67    0.60  0.58
# llama-3.2-90b-text-preview      0.88       0.95    0.88  0.91
# mixtral-8x7b-32768              0.84       0.94    0.84  0.88

# %%
metrics_n_sensor_llm = summarize_llm[(summarize_llm["sensors"] != "All") & (summarize_llm["model_name"] == "llama-3.2-11b-text-preview")].set_index(["sensors"]).iloc[:, -4:]

metrics_n_sensor_llm
# Out:
#            accuracy  precision  recall    f1
# sensors
# Acc            0.92        1.0    0.92  0.96
# Acc & WSA      0.72        1.0    0.72  0.84
# ST             0.91        1.0    0.91  0.95
# WS             1.00        1.0    1.00  1.00
# WSA            0.83        1.0    0.83  0.91
# YR             0.76        1.0    0.76  0.86

# %%
metrics_n_sensor_llm = summarize_llm[(summarize_llm["sensors"] != "All") & (summarize_llm["model_name"] == "llama-3.2-90b-text-preview")].set_index(["sensors"]).iloc[:, -4:]

metrics_n_sensor_llm
# Out:
#            accuracy  precision  recall    f1
# sensors
# Acc            0.96        1.0    0.96  0.98
# Acc & WSA      0.94        1.0    0.94  0.97
# ST             0.84        1.0    0.84  0.92
# WS             1.00        1.0    1.00  1.00
# WSA            0.67        1.0    0.67  0.80
# YR             0.90        1.0    0.90  0.95
